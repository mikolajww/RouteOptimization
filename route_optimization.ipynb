# %%
import gc
import numpy as np
import itertools as it
import math
import random
import string
from collections import namedtuple
from copy import deepcopy

from memory_profiler import memory_usage

random.seed()
x_range = (-100, 100)
y_range = (-100, 100)
z_range = (0, 50)
Point3 = namedtuple('Point3', ['x', 'y', 'z'])

# %%
class Graph:
    def __init__(self, n, *, x_range=(-100, 100), y_range=(-100, 100),
                 z_range=(0, 50), symmetrical=True, removed_percent=20, is_height_diff=True):
        self.city_labels = list((string.ascii_uppercase + string.ascii_lowercase + string.digits)[:n])
        self.vertices = {}
        for i in range(n):
            self.vertices[self.city_labels[i]] = Point3(random.uniform(*x_range), random.uniform(*y_range),
                                                        random.uniform(*z_range))

        self.edges = {}
        self.distances = {}
        self.all_edges = list(it.combinations(self.city_labels, 2))
        for city, position_a in self.vertices.items():
            self.edges[city] = []
            self.distances[city] = {}
            for other_city, position_b in self.vertices.items():
                d = self.dist(position_a, position_b)
                if (city == other_city):
                    self.distances[city][other_city] = d
                    continue
                self.edges[city].append(other_city)
                self.distances[city][other_city] = d
        if (removed_percent > 0):
            edges_copy = deepcopy(self.edges)
            items_to_remove = math.ceil(n / 100 * len(self.vertices))
            combs = [*it.combinations(self.edges, 2)]
            choices = random.sample(combs, items_to_remove)
            for choice in choices:
                _from, _to = choice
                self.edges[_from].remove(_to)
                if (symmetrical):
                    self.edges[_to].remove(_from)
                    
                    
    def dist(self, point_a, point_b, height_diff=True):
        d = math.sqrt((point_a.x - point_b.x) ** 2 + (point_a.y - point_b.y) ** 2 + (point_a.z - point_b.z) ** 2)
        if (height_diff):
            if point_a.z < point_b.z:
                d *= 1.1
            elif point_a.z > point_b.z:
                d *= 0.9
        return d

# %%
g = Graph(5)
g.edges
# Out:
# {'A': ['B', 'C', 'D', 'E'],
#  'B': ['A', 'C', 'D', 'E'],
#  'C': ['A', 'B', 'D', 'E'],
#  'D': ['A', 'B', 'C'],
#  'E': ['A', 'B', 'C']}

# %%
class State:
    def __init__(self, pos, previous=[], cost=0, parent=None, visited_edges=None):
        self.pos = pos
        if not visited_edges:
            self.visited_edges = []
        else:
            self.visited_edges = visited_edges.copy()

        if not previous:
            self.previous = [pos]
        else:
            self.previous = previous.copy()
        if len(self.previous) > 1:
            curr = pos
            prev = self.previous[-2]
            self.visited_edges.append((prev, curr))
            self.visited_edges.append((curr, prev))
        self.cost = cost
        self.parent = parent

    def __str__(self):
        return f"<Pos: {self.pos} | Cost: {self.cost:.3f} | Visited {self.previous}>"

    def __repr__(self):
        return self.__str__()

    def get_path(self):
        previous_paths = []
        self.__path(previous_paths)
        return '>'.join(reversed(previous_paths))

    def __path(self, previous):
        previous.append(self.pos)
        if self.parent is not None:
            self.parent.__path(previous)
        return previous

    def __eq__(self, other):
        return self.pos == other.pos and self.previous == other.previous
    
    def __lt__(self, other): #only for the sake of priority conflicts
        return True

    def expand(self, graph):
        children = []
        possible_routes = graph.edges[self.pos]
        for end_edge in possible_routes:
            route_cost = graph.distances[self.pos][end_edge]
            child = State(end_edge, [*self.previous, end_edge], self.cost + route_cost, self, self.visited_edges)
            children.append(child)
        return self._filter_invalid_and_visited(children, graph)

    def _filter_invalid_and_visited(self, potential_children, graph):
        # special case if we have completed a tour and need to return
        children = []
        if (len(self.previous) == len(graph.vertices)):
            initial_city = self.previous[0]
            for child in potential_children:
                if (child.pos == initial_city):
                    children.append(child)
                    # print(f"Returning to {initial_city} from {child}")
        else:
            for child in potential_children:
                if (child.pos not in self.previous):
                    children.append(child)
        # print(f"removed invalid states {[c for c in potential_children if c not in children]}")
        return children

# %%
def is_goal_state(state, initial_state, graph):
    if state.pos == initial_state.pos and len(state.previous) == len(graph.vertices) + 1:
        #todo check if all letters are present?
        return True
    return False


def pretty_print(mode, size, fn_to_eval):
    result, t = fn_to_eval()
    print(f"    [{mode} | n={size}] Final cost: {result.cost:.3f} | Time: {t:.8f}s | Path: {result.get_path()}")


def log_results(df, removed_percent, symmetrical, mode, size, fn_to_eval):
    gc.collect()
    ipython_memory_footprint = memory_usage(-1, max_usage=True, max_iterations=1)
    max_alloc, fnresult = memory_usage((fn_to_eval, (), {}), max_usage=True, retval=True, max_iterations=1)
    (result, t) = fnresult
    alloc_diff = max_alloc-ipython_memory_footprint
    df.append({'size': size, 'removed_percent': removed_percent, 
                'symmetrical' : symmetrical, 'alg_name': mode, 
                'cost': result.cost, 'time': t, 
                'path': result.get_path(), 'max_alloc': alloc_diff})
    print(f"    [{mode} | n={size}] Cost: {result.cost:.2f} | Time: {t:.4f}s | Path: {result.get_path()} | Max alloc {alloc_diff:.4f} MB")

# %%
from queue import PriorityQueue

def full_search(graph, start, mode='bfs'):
    start_time = time.time()

    pop_idx = {'bfs': 0, 'dfs': -1}
    candidate_nodes = []
    starting_point = State(start)
    candidate_nodes.append(starting_point)
    leaves = []
    while candidate_nodes:
        s = candidate_nodes.pop(pop_idx[mode])
        if is_goal_state(s, starting_point, graph):
            leaves.append(s)
        new_candidates = s.expand(graph)
        candidate_nodes.extend(new_candidates)
    final_best = min(leaves, key=lambda x: x.cost)

    total_time = time.time() - start_time
    return final_best, total_time


def nearest_neighbour(graph, start):
    start_time = time.time()
    starting_point = State(start)
    current_point = starting_point
    dead_ends = []
    while True:
        neighbours = current_point.expand(graph)
        neighbours = [n for n in neighbours if n not in dead_ends]  # exclude dead ends from calculation
        if neighbours:
            nn = min(neighbours, key=lambda x: x.cost)
            current_point = nn
            if is_goal_state(current_point, starting_point, graph):  # we are done
                break
        else:  # no neighbours
            if is_goal_state(current_point, starting_point, graph):  # leaf satisfies full path - we are done
                break
            else:  # we are stuck
                # print(f"stuck at {current_point}")
                if current_point not in dead_ends:
                    dead_ends.append(current_point)
                current_point = current_point.parent  # backtrack
    total_time = time.time() - start_time
    return current_point, total_time


def heuristic_search(graph, start, heuristic):
    start_time = time.time()
    candidate_nodes = PriorityQueue()
    starting_point = State(start)
    candidate_nodes.put((0, starting_point))

    while candidate_nodes:
        _, current_node = candidate_nodes.get()
        if is_goal_state(current_node, starting_point, graph):
            break
        new_candidates = current_node.expand(graph)
        if new_candidates:
            for candidate in new_candidates:
                predicted_cost = candidate.cost + heuristic(candidate, graph)
                candidate_nodes.put((predicted_cost, candidate))
    total_time = time.time() - start_time
    return current_node, total_time


def dijkstra_heuristic(current, graph):
    return 0


def a_star_min_heuristic(current, graph):
    # min cost of remaining paths * number of remaining cities to visit
    cities_to_visit = len(graph.vertices) - len(current.previous) + 1 # return path
    visited_so_far = current.visited_edges
    remaining_edges = graph.all_edges.copy()
    for visited_start, visited_end in visited_so_far:
        if (visited_start, visited_end) in remaining_edges:
            remaining_edges.remove((visited_start, visited_end))
    cost_list = list(map(lambda edge: graph.distances[edge[0]][edge[1]], remaining_edges))
    if len(remaining_edges) == 0:
        return 0
    return min(cost_list) * cities_to_visit


def a_star_avg_heuristic(current, graph):
    # average cost of remaining paths * number of remaining cities to visit
    cities_to_visit = len(graph.vertices) - len(current.previous) + 1 # return path
    visited_so_far = current.visited_edges
    remaining_edges = graph.all_edges.copy()
    for visited_start, visited_end in visited_so_far:
        if ((visited_start, visited_end) in remaining_edges):
            remaining_edges.remove((visited_start, visited_end))
    cost_list = list(map(lambda edge: graph.distances[edge[0]][edge[1]], remaining_edges))
    if len(remaining_edges) == 0:
        return 0
    return (sum(cost_list) / len(cost_list)) * cities_to_visit

def aco(graph, ants, iterations, evaporation=0.2, alpha=1, beta=2):
    start_time = time.time()
    #initialise pheromone matrix
    phero_matrix = {}
    for city in graph.vertices.keys():
        phero_matrix[city] = {}
        for other_city in graph.vertices.keys():
            phero_matrix[city][other_city] = 1
    #for each iteration
    for i in range(iterations):
        #initalize empty list of completed tours
        completed_tours = []
        for ant in range(ants):
            #pick random vertex to start from
            starting_point = State(random.choice([*graph.vertices.keys()]))
            current_node = starting_point
            while True:
                if(is_goal_state(current_node, starting_point, graph)):
                    completed_tours.append(current_node)
                    break
                children = current_node.expand(graph)
                if children:
                    nearby_cities = [point.pos for point in children]
                    #calculate total pheromones on nearby cities
                    nearby_phero = [(phero_matrix[current_node.pos][end_point]**alpha) * \
                                    (1/graph.distances[current_node.pos][end_point]**beta) \
                                    for end_point in nearby_cities] #pheromone^alpha * visibility^beta
                    total_nearby_phero = sum(nearby_phero)
                    next_node = np.random.choice(children, p=np.divide(nearby_phero, total_nearby_phero))
                    current_node = next_node
                else:
                    #the ant can't reach, we let it die
                    break
        #evaporate
        for phero_from in phero_matrix.keys():
            for phero_to in phero_matrix.keys():
                phero_matrix[phero_from][phero_to] *= 1 - evaporation
        #apply pheromones for each completed tour
        for completed_tour in completed_tours:
            for start, end in zip(completed_tour.previous, completed_tour.previous[1:]):
                phero_matrix[start][end] += 1/completed_tour.cost
    best = min(completed_tours, key=lambda x: x.cost)
                                                 
    return best, time.time() - start_time

# %%
import time
import pandas as pd

removed_percents = [0, 20]

df = []
for n in range(5, 21):
    for removed_percent in [0, 20]:
        for symmetrical in [True, False]:
            print(f"Trying n = {n} | removed {removed_percent} % | symmetrical - {symmetrical}")
            graph = Graph(n, removed_percent=removed_percent, symmetrical=symmetrical)
            inital_city = 'A'
            
            if(n < 10):
                log_results(df, removed_percent, symmetrical, "dfs        ", n, lambda : full_search(graph, inital_city, "dfs"))
                log_results(df, removed_percent, symmetrical, "bfs        ", n, lambda : full_search(graph, inital_city, "bfs"))
            log_results(df, removed_percent, symmetrical, "nn         ", n, lambda : nearest_neighbour(graph, inital_city))
            if(n < 11):
                log_results(df, removed_percent, symmetrical, "dijkstra   ", n, lambda : heuristic_search(graph, inital_city, dijkstra_heuristic))
            if(n < 13):
                log_results(df, removed_percent, symmetrical, "a_star_min ", n, lambda : heuristic_search(graph, inital_city, a_star_min_heuristic))
            log_results(df, removed_percent, symmetrical, "a_star_avg ", n, lambda : heuristic_search(graph, inital_city, a_star_avg_heuristic))
            
            log_results(df, removed_percent, symmetrical, "aco        ", n, lambda : aco(graph, 25, 100))
            gc.collect()
#df = pd.DataFrame(df, columns = ['size', 'removed_percent', 'symmetrical', 'alg_name', 'cost', 'time', 'path', 'max_alloc'])
#df.to_excel(f'lab_1_results.xlsx')
# Out:
# Trying n = 5 | removed 0 % | symmetrical - True
#     [dfs         | n=5] Cost: 535.27 | Time: 0.0000s | Path: A>B>E>C>D>A | Max alloc 0.3203 MB
#     [bfs         | n=5] Cost: 535.27 | Time: 0.0000s | Path: A>B>E>C>D>A | Max alloc 0.0000 MB
#     [nn          | n=5] Cost: 555.68 | Time: 0.0000s | Path: A>D>C>E>B>A | Max alloc 0.0039 MB
#     [dijkstra    | n=5] Cost: 535.27 | Time: 0.0010s | Path: A>B>E>C>D>A | Max alloc 0.0000 MB
#     [a_star_min  | n=5] Cost: 535.27 | Time: 0.0010s | Path: A>B>E>C>D>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=5] Cost: 555.68 | Time: 0.0000s | Path: A>D>C>E>B>A | Max alloc 0.0000 MB
#     [aco         | n=5] Cost: 535.27 | Time: 0.4274s | Path: C>D>A>B>E>C | Max alloc 0.1211 MB
# Trying n = 5 | removed 0 % | symmetrical - False
#     [dfs         | n=5] Cost: 430.75 | Time: 0.0010s | Path: A>D>B>C>E>A | Max alloc 0.0000 MB
#     [bfs         | n=5] Cost: 430.75 | Time: 0.0000s | Path: A>D>B>C>E>A | Max alloc 0.0000 MB
#     [nn          | n=5] Cost: 465.92 | Time: 0.0010s | Path: A>E>D>B>C>A | Max alloc 0.0000 MB
#     [dijkstra    | n=5] Cost: 430.75 | Time: 0.0010s | Path: A>D>B>C>E>A | Max alloc 0.0000 MB
#     [a_star_min  | n=5] Cost: 430.75 | Time: 0.0000s | Path: A>D>B>C>E>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=5] Cost: 465.92 | Time: 0.0000s | Path: A>E>D>B>C>A | Max alloc 0.0000 MB
#     [aco         | n=5] Cost: 430.75 | Time: 0.4255s | Path: C>E>A>D>B>C | Max alloc 0.0000 MB
# Trying n = 5 | removed 20 % | symmetrical - True
#     [dfs         | n=5] Cost: 600.51 | Time: 0.0000s | Path: A>C>B>D>E>A | Max alloc 0.0000 MB
#     [bfs         | n=5] Cost: 600.51 | Time: 0.0000s | Path: A>C>B>D>E>A | Max alloc 0.0000 MB
#     [nn          | n=5] Cost: 603.68 | Time: 0.0010s | Path: A>E>D>B>C>A | Max alloc 0.0000 MB
#     [dijkstra    | n=5] Cost: 600.51 | Time: 0.0000s | Path: A>C>B>D>E>A | Max alloc 0.0000 MB
#     [a_star_min  | n=5] Cost: 600.51 | Time: 0.0000s | Path: A>C>B>D>E>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=5] Cost: 603.68 | Time: 0.0000s | Path: A>E>D>B>C>A | Max alloc 0.0000 MB
#     [aco         | n=5] Cost: 600.51 | Time: 0.4074s | Path: E>A>C>B>D>E | Max alloc 0.0078 MB
# Trying n = 5 | removed 20 % | symmetrical - False
#     [dfs         | n=5] Cost: 474.94 | Time: 0.0010s | Path: A>E>D>C>B>A | Max alloc 0.0000 MB
#     [bfs         | n=5] Cost: 474.94 | Time: 0.0000s | Path: A>E>D>C>B>A | Max alloc 0.0000 MB
#     [nn          | n=5] Cost: 558.62 | Time: 0.0000s | Path: A>E>B>D>C>A | Max alloc 0.0000 MB
#     [dijkstra    | n=5] Cost: 474.94 | Time: 0.0000s | Path: A>E>D>C>B>A | Max alloc 0.0000 MB
#     [a_star_min  | n=5] Cost: 474.94 | Time: 0.0000s | Path: A>E>D>C>B>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=5] Cost: 474.94 | Time: 0.0010s | Path: A>E>D>C>B>A | Max alloc 0.0000 MB
#     [aco         | n=5] Cost: 474.94 | Time: 0.4124s | Path: A>E>D>C>B>A | Max alloc 0.0000 MB
# Trying n = 6 | removed 0 % | symmetrical - True
#     [dfs         | n=6] Cost: 452.97 | Time: 0.0040s | Path: A>E>D>C>F>B>A | Max alloc 0.2500 MB
#     [bfs         | n=6] Cost: 452.97 | Time: 0.0040s | Path: A>E>D>C>F>B>A | Max alloc 0.0000 MB
#     [nn          | n=6] Cost: 452.97 | Time: 0.0000s | Path: A>E>D>C>F>B>A | Max alloc 0.0000 MB
#     [dijkstra    | n=6] Cost: 452.97 | Time: 0.0020s | Path: A>E>D>C>F>B>A | Max alloc 0.0000 MB
#     [a_star_min  | n=6] Cost: 452.97 | Time: 0.0020s | Path: A>E>D>C>F>B>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=6] Cost: 452.97 | Time: 0.0000s | Path: A>E>D>C>F>B>A | Max alloc 0.0000 MB
#     [aco         | n=6] Cost: 452.97 | Time: 0.5391s | Path: A>E>D>C>F>B>A | Max alloc 0.0000 MB
# Trying n = 6 | removed 0 % | symmetrical - False
#     [dfs         | n=6] Cost: 438.78 | Time: 0.0040s | Path: A>B>D>E>C>F>A | Max alloc 0.0000 MB
#     [bfs         | n=6] Cost: 438.78 | Time: 0.0040s | Path: A>B>D>E>C>F>A | Max alloc 0.0000 MB
#     [nn          | n=6] Cost: 500.64 | Time: 0.0000s | Path: A>F>C>E>D>B>A | Max alloc 0.0000 MB
#     [dijkstra    | n=6] Cost: 438.78 | Time: 0.0030s | Path: A>B>D>E>C>F>A | Max alloc 0.0000 MB
#     [a_star_min  | n=6] Cost: 438.78 | Time: 0.0030s | Path: A>B>D>E>C>F>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=6] Cost: 491.70 | Time: 0.0010s | Path: A>F>C>D>E>B>A | Max alloc 0.0000 MB
#     [aco         | n=6] Cost: 438.78 | Time: 0.5365s | Path: D>E>C>F>A>B>D | Max alloc 0.0000 MB
# Trying n = 6 | removed 20 % | symmetrical - True
#     [dfs         | n=6] Cost: 413.41 | Time: 0.0030s | Path: A>C>E>B>F>D>A | Max alloc 0.0000 MB
#     [bfs         | n=6] Cost: 413.41 | Time: 0.0020s | Path: A>C>E>B>F>D>A | Max alloc 0.0000 MB
#     [nn          | n=6] Cost: 481.19 | Time: 0.0000s | Path: A>C>B>F>D>E>A | Max alloc 0.0000 MB
#     [dijkstra    | n=6] Cost: 413.41 | Time: 0.0020s | Path: A>C>E>B>F>D>A | Max alloc 0.0000 MB
#     [a_star_min  | n=6] Cost: 413.41 | Time: 0.0030s | Path: A>C>E>B>F>D>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=6] Cost: 481.19 | Time: 0.0000s | Path: A>C>B>F>D>E>A | Max alloc 0.0000 MB
#     [aco         | n=6] Cost: 413.90 | Time: 0.5238s | Path: E>B>C>A>F>D>E | Max alloc 0.0000 MB
# Trying n = 6 | removed 20 % | symmetrical - False
#     [dfs         | n=6] Cost: 363.62 | Time: 0.0020s | Path: A>E>C>D>F>B>A | Max alloc 0.0000 MB
#     [bfs         | n=6] Cost: 363.62 | Time: 0.0030s | Path: A>E>C>D>F>B>A | Max alloc 0.0000 MB
#     [nn          | n=6] Cost: 426.02 | Time: 0.0000s | Path: A>F>B>D>E>C>A | Max alloc 0.0000 MB
#     [dijkstra    | n=6] Cost: 363.62 | Time: 0.0020s | Path: A>E>C>D>F>B>A | Max alloc 0.0000 MB
#     [a_star_min  | n=6] Cost: 363.62 | Time: 0.0020s | Path: A>E>C>D>F>B>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=6] Cost: 426.02 | Time: 0.0000s | Path: A>F>B>D>E>C>A | Max alloc 0.0000 MB
#     [aco         | n=6] Cost: 363.62 | Time: 0.5295s | Path: A>E>C>D>F>B>A | Max alloc 0.0000 MB
# Trying n = 7 | removed 0 % | symmetrical - True
#     [dfs         | n=7] Cost: 539.03 | Time: 0.0250s | Path: A>D>F>E>B>C>G>A | Max alloc 1.1250 MB
#     [bfs         | n=7] Cost: 539.03 | Time: 0.0250s | Path: A>D>F>E>B>C>G>A | Max alloc 0.7500 MB
#     [nn          | n=7] Cost: 541.79 | Time: 0.0000s | Path: A>G>C>B>E>F>D>A | Max alloc 0.0000 MB
#     [dijkstra    | n=7] Cost: 539.03 | Time: 0.0140s | Path: A>D>F>E>B>C>G>A | Max alloc 0.0039 MB
#     [a_star_min  | n=7] Cost: 539.03 | Time: 0.0210s | Path: A>D>F>E>B>C>G>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=7] Cost: 556.94 | Time: 0.0000s | Path: A>G>E>B>C>F>D>A | Max alloc 0.0000 MB
#     [aco         | n=7] Cost: 539.03 | Time: 0.6676s | Path: G>A>D>F>E>B>C>G | Max alloc 0.0039 MB
# Trying n = 7 | removed 0 % | symmetrical - False
#     [dfs         | n=7] Cost: 492.20 | Time: 0.0250s | Path: A>F>G>C>B>E>D>A | Max alloc 0.3750 MB
#     [bfs         | n=7] Cost: 492.20 | Time: 0.0250s | Path: A>F>G>C>B>E>D>A | Max alloc 0.2539 MB
#     [nn          | n=7] Cost: 501.83 | Time: 0.0000s | Path: A>F>G>C>E>B>D>A | Max alloc 0.0000 MB
#     [dijkstra    | n=7] Cost: 492.20 | Time: 0.0100s | Path: A>F>G>C>B>E>D>A | Max alloc 0.0000 MB
#     [a_star_min  | n=7] Cost: 492.20 | Time: 0.0120s | Path: A>F>G>C>B>E>D>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=7] Cost: 501.83 | Time: 0.0000s | Path: A>F>G>C>E>B>D>A | Max alloc 0.0000 MB
#     [aco         | n=7] Cost: 492.20 | Time: 0.6814s | Path: D>A>F>G>C>B>E>D | Max alloc 0.0000 MB
# Trying n = 7 | removed 20 % | symmetrical - True
#     [dfs         | n=7] Cost: 397.87 | Time: 0.0170s | Path: A>E>D>F>B>G>C>A | Max alloc 0.0000 MB
#     [bfs         | n=7] Cost: 397.87 | Time: 0.0170s | Path: A>E>D>F>B>G>C>A | Max alloc 0.0000 MB
#     [nn          | n=7] Cost: 458.38 | Time: 0.0000s | Path: A>E>D>C>G>B>F>A | Max alloc 0.0000 MB
#     [dijkstra    | n=7] Cost: 397.87 | Time: 0.0100s | Path: A>E>D>F>B>G>C>A | Max alloc 0.0000 MB
#     [a_star_min  | n=7] Cost: 397.87 | Time: 0.0100s | Path: A>E>D>F>B>G>C>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=7] Cost: 458.38 | Time: 0.0000s | Path: A>E>D>C>G>B>F>A | Max alloc 0.0000 MB
#     [aco         | n=7] Cost: 397.87 | Time: 0.6603s | Path: A>E>D>F>B>G>C>A | Max alloc 0.0000 MB
# Trying n = 7 | removed 20 % | symmetrical - False
#     [dfs         | n=7] Cost: 537.47 | Time: 0.0200s | Path: A>D>B>C>E>G>F>A | Max alloc 0.0000 MB
#     [bfs         | n=7] Cost: 537.47 | Time: 0.0200s | Path: A>D>B>C>E>G>F>A | Max alloc 0.0000 MB
#     [nn          | n=7] Cost: 685.70 | Time: 0.0000s | Path: A>F>E>C>B>D>G>A | Max alloc 0.0000 MB
#     [dijkstra    | n=7] Cost: 537.47 | Time: 0.0090s | Path: A>D>B>C>E>G>F>A | Max alloc 0.0000 MB
#     [a_star_min  | n=7] Cost: 537.47 | Time: 0.0060s | Path: A>D>B>C>E>G>F>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=7] Cost: 653.72 | Time: 0.0000s | Path: A>F>E>C>D>B>G>A | Max alloc 0.0000 MB
#     [aco         | n=7] Cost: 537.47 | Time: 0.6736s | Path: G>F>A>D>B>C>E>G | Max alloc 0.0000 MB
# Trying n = 8 | removed 0 % | symmetrical - True
#     [dfs         | n=8] Cost: 551.64 | Time: 0.2322s | Path: A>G>B>D>C>E>F>H>A | Max alloc 8.7422 MB
#     [bfs         | n=8] Cost: 551.64 | Time: 0.2352s | Path: A>G>B>D>C>E>F>H>A | Max alloc 10.0195 MB
#     [nn          | n=8] Cost: 640.63 | Time: 0.0010s | Path: A>F>H>E>C>D>B>G>A | Max alloc 0.0000 MB
#     [dijkstra    | n=8] Cost: 551.64 | Time: 0.0450s | Path: A>G>B>D>C>E>F>H>A | Max alloc 0.6250 MB
#     [a_star_min  | n=8] Cost: 551.64 | Time: 0.0951s | Path: A>G>B>D>C>E>F>H>A | Max alloc 0.1250 MB
#     [a_star_avg  | n=8] Cost: 665.64 | Time: 0.0010s | Path: A>F>H>E>C>B>G>D>A | Max alloc 0.0000 MB
#     [aco         | n=8] Cost: 551.64 | Time: 0.8097s | Path: D>C>E>F>H>A>G>B>D | Max alloc 0.0000 MB
# Trying n = 8 | removed 0 % | symmetrical - False
#     [dfs         | n=8] Cost: 563.73 | Time: 0.2290s | Path: A>E>C>H>F>B>D>G>A | Max alloc 6.8750 MB
#     [bfs         | n=8] Cost: 563.73 | Time: 0.2372s | Path: A>E>C>H>F>B>D>G>A | Max alloc 7.9961 MB
#     [nn          | n=8] Cost: 619.74 | Time: 0.0000s | Path: A>G>D>E>C>H>F>B>A | Max alloc 0.0000 MB
#     [dijkstra    | n=8] Cost: 563.73 | Time: 0.0470s | Path: A>E>C>H>F>B>D>G>A | Max alloc 0.0039 MB
#     [a_star_min  | n=8] Cost: 563.73 | Time: 0.0440s | Path: A>E>C>H>F>B>D>G>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=8] Cost: 619.74 | Time: 0.0000s | Path: A>G>D>E>C>H>F>B>A | Max alloc 0.0000 MB
#     [aco         | n=8] Cost: 563.73 | Time: 0.8137s | Path: B>D>G>A>E>C>H>F>B | Max alloc 0.0000 MB
# Trying n = 8 | removed 20 % | symmetrical - True
#     [dfs         | n=8] Cost: 421.00 | Time: 0.1443s | Path: A>E>C>H>B>D>F>G>A | Max alloc 1.2734 MB
#     [bfs         | n=8] Cost: 421.00 | Time: 0.1612s | Path: A>E>C>H>B>D>F>G>A | Max alloc 2.2930 MB
#     [nn          | n=8] Cost: 474.36 | Time: 0.0000s | Path: A>E>C>H>F>G>B>D>A | Max alloc 0.0000 MB
#     [dijkstra    | n=8] Cost: 421.00 | Time: 0.0430s | Path: A>E>C>H>B>D>F>G>A | Max alloc 0.0000 MB
#     [a_star_min  | n=8] Cost: 421.00 | Time: 0.0721s | Path: A>E>C>H>B>D>F>G>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=8] Cost: 490.52 | Time: 0.0010s | Path: A>E>C>H>F>B>D>G>A | Max alloc 0.0000 MB
#     [aco         | n=8] Cost: 421.00 | Time: 0.7991s | Path: A>E>C>H>B>D>F>G>A | Max alloc 0.0000 MB
# Trying n = 8 | removed 20 % | symmetrical - False
#     [dfs         | n=8] Cost: 574.47 | Time: 0.2077s | Path: A>F>B>C>D>H>G>E>A | Max alloc 4.5078 MB
#     [bfs         | n=8] Cost: 574.47 | Time: 0.2232s | Path: A>F>B>C>D>H>G>E>A | Max alloc 4.7617 MB
#     [nn          | n=8] Cost: 602.29 | Time: 0.0010s | Path: A>H>E>F>B>C>D>G>A | Max alloc 0.0000 MB
#     [dijkstra    | n=8] Cost: 574.47 | Time: 0.0509s | Path: A>F>B>C>D>H>G>E>A | Max alloc 0.0039 MB
#     [a_star_min  | n=8] Cost: 574.47 | Time: 0.0540s | Path: A>F>B>C>D>H>G>E>A | Max alloc 0.0508 MB
#     [a_star_avg  | n=8] Cost: 602.29 | Time: 0.0000s | Path: A>H>E>F>B>C>D>G>A | Max alloc 0.0000 MB
#     [aco         | n=8] Cost: 580.58 | Time: 0.8195s | Path: H>F>B>C>D>G>E>A>H | Max alloc 0.0000 MB
# Trying n = 9 | removed 0 % | symmetrical - True
#     [dfs         | n=9] Cost: 587.90 | Time: 2.2632s | Path: A>H>F>B>G>D>I>E>C>A | Max alloc 91.9648 MB
#     [bfs         | n=9] Cost: 587.90 | Time: 3.2535s | Path: A>H>F>B>G>D>I>E>C>A | Max alloc 93.9414 MB
#     [nn          | n=9] Cost: 602.31 | Time: 0.0000s | Path: A>H>E>F>B>G>D>I>C>A | Max alloc 0.0000 MB
#     [dijkstra    | n=9] Cost: 587.90 | Time: 0.5504s | Path: A>H>F>B>G>D>I>E>C>A | Max alloc 21.3047 MB
#     [a_star_min  | n=9] Cost: 587.90 | Time: 0.8744s | Path: A>H>F>B>G>D>I>E>C>A | Max alloc 14.3125 MB
#     [a_star_avg  | n=9] Cost: 618.93 | Time: 0.0010s | Path: A>H>E>B>F>G>D>I>C>A | Max alloc 0.0000 MB
#     [aco         | n=9] Cost: 601.63 | Time: 0.9810s | Path: E>H>A>C>F>B>G>D>I>E | Max alloc 0.0000 MB
# Trying n = 9 | removed 0 % | symmetrical - False
#     [dfs         | n=9] Cost: 620.83 | Time: 2.2489s | Path: A>F>G>H>C>D>I>E>B>A | Max alloc 90.0625 MB
#     [bfs         | n=9] Cost: 620.83 | Time: 3.2371s | Path: A>F>G>H>C>D>I>E>B>A | Max alloc 91.5000 MB
#     [nn          | n=9] Cost: 752.53 | Time: 0.0000s | Path: A>B>C>H>F>G>D>E>I>A | Max alloc 0.0039 MB
#     [dijkstra    | n=9] Cost: 620.83 | Time: 0.3904s | Path: A>F>G>H>C>D>I>E>B>A | Max alloc 16.0000 MB
#     [a_star_min  | n=9] Cost: 620.83 | Time: 0.1331s | Path: A>F>G>H>C>D>I>E>B>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=9] Cost: 752.53 | Time: 0.0000s | Path: A>B>C>H>F>G>D>E>I>A | Max alloc 0.0000 MB
#     [aco         | n=9] Cost: 620.83 | Time: 0.9634s | Path: E>B>A>F>G>H>C>D>I>E | Max alloc 0.0000 MB
# Trying n = 9 | removed 20 % | symmetrical - True
#     [dfs         | n=9] Cost: 593.34 | Time: 1.6843s | Path: A>H>B>C>E>I>D>F>G>A | Max alloc 62.0000 MB
#     [bfs         | n=9] Cost: 593.34 | Time: 2.2831s | Path: A>H>B>C>E>I>D>F>G>A | Max alloc 66.0625 MB
#     [nn          | n=9] Cost: 692.21 | Time: 0.0000s | Path: A>H>C>B>I>D>G>F>E>A | Max alloc 0.0000 MB
#     [dijkstra    | n=9] Cost: 593.34 | Time: 0.3365s | Path: A>H>B>C>E>I>D>F>G>A | Max alloc 8.1250 MB
#     [a_star_min  | n=9] Cost: 593.34 | Time: 0.4794s | Path: A>H>B>C>E>I>D>F>G>A | Max alloc 1.2500 MB
#     [a_star_avg  | n=9] Cost: 692.21 | Time: 0.0000s | Path: A>H>C>B>I>D>G>F>E>A | Max alloc 0.0000 MB
#     [aco         | n=9] Cost: 593.34 | Time: 0.9479s | Path: A>H>B>C>E>I>D>F>G>A | Max alloc 0.0000 MB
# Trying n = 9 | removed 20 % | symmetrical - False
#     [dfs         | n=9] Cost: 623.28 | Time: 2.0434s | Path: A>C>G>D>I>B>E>H>F>A | Max alloc 74.5000 MB
#     [bfs         | n=9] Cost: 623.28 | Time: 2.6876s | Path: A>C>G>D>I>B>E>H>F>A | Max alloc 75.8086 MB
#     [nn          | n=9] Cost: 649.79 | Time: 0.0000s | Path: A>C>G>I>D>E>B>H>F>A | Max alloc 0.0000 MB
#     [dijkstra    | n=9] Cost: 623.28 | Time: 0.2498s | Path: A>C>G>D>I>B>E>H>F>A | Max alloc 4.9727 MB
#     [a_star_min  | n=9] Cost: 623.28 | Time: 0.3273s | Path: A>C>G>D>I>B>E>H>F>A | Max alloc 0.2188 MB
#     [a_star_avg  | n=9] Cost: 649.79 | Time: 0.0000s | Path: A>C>G>I>D>E>B>H>F>A | Max alloc 0.0000 MB
#     [aco         | n=9] Cost: 635.48 | Time: 0.9659s | Path: E>B>I>D>G>C>A>F>H>E | Max alloc 0.0000 MB
# Trying n = 10 | removed 0 % | symmetrical - True
#     [nn          | n=10] Cost: 682.18 | Time: 0.0000s | Path: A>H>I>G>D>B>J>C>F>E>A | Max alloc 0.0000 MB
#     [dijkstra    | n=10] Cost: 618.69 | Time: 1.4333s | Path: A>E>F>H>I>G>D>B>J>C>A | Max alloc 68.6250 MB
#     [a_star_min  | n=10] Cost: 618.69 | Time: 0.8077s | Path: A>E>F>H>I>G>D>B>J>C>A | Max alloc 4.6836 MB
#     [a_star_avg  | n=10] Cost: 682.18 | Time: 0.0010s | Path: A>H>I>G>D>B>J>C>F>E>A | Max alloc 0.0000 MB
#     [aco         | n=10] Cost: 618.69 | Time: 1.1571s | Path: E>F>H>I>G>D>B>J>C>A>E | Max alloc 0.0000 MB
# Trying n = 10 | removed 0 % | symmetrical - False
#     [nn          | n=10] Cost: 632.09 | Time: 0.0010s | Path: A>C>J>B>D>E>I>H>F>G>A | Max alloc 0.0000 MB
#     [dijkstra    | n=10] Cost: 595.50 | Time: 2.5212s | Path: A>C>J>E>D>B>I>H>G>F>A | Max alloc 115.3828 MB
#     [a_star_min  | n=10] Cost: 595.50 | Time: 3.6863s | Path: A>C>J>E>D>B>I>H>G>F>A | Max alloc 67.8320 MB
#     [a_star_avg  | n=10] Cost: 703.61 | Time: 0.0010s | Path: A>C>J>B>D>I>H>F>G>E>A | Max alloc 0.0000 MB
#     [aco         | n=10] Cost: 600.79 | Time: 1.1281s | Path: E>D>B>I>H>F>G>A>C>J>E | Max alloc 0.0000 MB
# Trying n = 10 | removed 20 % | symmetrical - True
#     [nn          | n=10] Cost: 699.83 | Time: 0.0000s | Path: A>F>D>G>J>B>E>I>C>H>A | Max alloc 0.0000 MB
#     [dijkstra    | n=10] Cost: 516.85 | Time: 0.7497s | Path: A>F>D>H>G>J>B>E>I>C>A | Max alloc 29.7656 MB
#     [a_star_min  | n=10] Cost: 516.85 | Time: 1.0319s | Path: A>F>D>H>G>J>B>E>I>C>A | Max alloc 8.8398 MB
#     [a_star_avg  | n=10] Cost: 650.09 | Time: 0.0010s | Path: A>F>D>C>I>G>J>B>E>H>A | Max alloc 0.0000 MB
#     [aco         | n=10] Cost: 516.85 | Time: 1.1270s | Path: G>J>B>E>I>C>A>F>D>H>G | Max alloc 0.0000 MB
# Trying n = 10 | removed 20 % | symmetrical - False
#     [nn          | n=10] Cost: 629.14 | Time: 0.0000s | Path: A>D>G>B>F>C>H>I>E>J>A | Max alloc 0.0000 MB
#     [dijkstra    | n=10] Cost: 549.53 | Time: 3.2899s | Path: A>D>G>B>F>J>E>I>H>C>A | Max alloc 150.0195 MB
#     [a_star_min  | n=10] Cost: 549.53 | Time: 3.3741s | Path: A>D>G>B>F>J>E>I>H>C>A | Max alloc 58.3750 MB
#     [a_star_avg  | n=10] Cost: 622.06 | Time: 0.0010s | Path: A>D>B>F>G>C>H>I>E>J>A | Max alloc 0.0000 MB
#     [aco         | n=10] Cost: 549.53 | Time: 1.1185s | Path: D>G>B>F>J>E>I>H>C>A>D | Max alloc 0.0000 MB
# Trying n = 11 | removed 0 % | symmetrical - True
#     [nn          | n=11] Cost: 738.66 | Time: 0.0010s | Path: A>H>I>K>G>F>C>E>D>B>J>A | Max alloc 0.0000 MB
#     [a_star_min  | n=11] Cost: 656.25 | Time: 23.2404s | Path: A>H>I>K>J>G>B>D>E>C>F>A | Max alloc 417.5703 MB
#     [a_star_avg  | n=11] Cost: 738.90 | Time: 0.0010s | Path: A>H>I>K>G>J>C>F>B>D>E>A | Max alloc 0.0000 MB
#     [aco         | n=11] Cost: 660.27 | Time: 1.3182s | Path: H>I>K>G>J>B>D>E>C>F>A>H | Max alloc 0.0000 MB
# Trying n = 11 | removed 0 % | symmetrical - False
#     [nn          | n=11] Cost: 566.80 | Time: 0.0000s | Path: A>G>C>F>K>B>E>J>I>D>H>A | Max alloc 0.0000 MB
#     [a_star_min  | n=11] Cost: 550.78 | Time: 20.9603s | Path: A>K>B>E>J>I>D>H>C>F>G>A | Max alloc 377.6680 MB
#     [a_star_avg  | n=11] Cost: 711.98 | Time: 0.0020s | Path: A>G>C>F>K>B>E>I>D>H>J>A | Max alloc 0.0000 MB
#     [aco         | n=11] Cost: 550.78 | Time: 1.3042s | Path: G>A>K>B>E>J>I>D>H>C>F>G | Max alloc 0.0000 MB
# Trying n = 11 | removed 20 % | symmetrical - True
#     [nn          | n=11] Cost: 833.98 | Time: 0.0010s | Path: A>G>J>C>D>K>F>I>B>H>E>A | Max alloc 0.0000 MB
#     [a_star_min  | n=11] Cost: 691.84 | Time: 14.6347s | Path: A>G>C>J>E>D>I>F>K>B>H>A | Max alloc 258.5469 MB
#     [a_star_avg  | n=11] Cost: 833.98 | Time: 0.0020s | Path: A>G>J>C>D>K>F>I>B>H>E>A | Max alloc 0.0000 MB
#     [aco         | n=11] Cost: 696.44 | Time: 1.3417s | Path: H>K>F>I>D>E>J>C>G>A>B>H | Max alloc 0.0000 MB
# Trying n = 11 | removed 20 % | symmetrical - False
#     [nn          | n=11] Cost: 654.81 | Time: 0.0000s | Path: A>B>E>F>J>D>H>G>C>K>I>A | Max alloc 0.0000 MB
#     [a_star_min  | n=11] Cost: 601.58 | Time: 4.3751s | Path: A>B>E>F>H>G>D>J>C>I>K>A | Max alloc 69.6875 MB
#     [a_star_avg  | n=11] Cost: 654.81 | Time: 0.0010s | Path: A>B>E>F>J>D>H>G>C>K>I>A | Max alloc 0.0000 MB
#     [aco         | n=11] Cost: 601.83 | Time: 1.2950s | Path: K>I>A>B>E>F>H>G>D>J>C>K | Max alloc 0.0000 MB
# Trying n = 12 | removed 0 % | symmetrical - True
#     [nn          | n=12] Cost: 951.67 | Time: 0.0000s | Path: A>E>C>H>G>J>I>D>B>K>F>L>A | Max alloc 0.0000 MB
#     [a_star_min  | n=12] Cost: 814.82 | Time: 95.4895s | Path: A>E>D>K>B>F>L>I>J>G>H>C>A | Max alloc 1582.9727 MB
#     [a_star_avg  | n=12] Cost: 951.67 | Time: 0.0020s | Path: A>E>C>H>G>J>I>D>B>K>F>L>A | Max alloc 0.0000 MB
#     [aco         | n=12] Cost: 871.52 | Time: 1.4821s | Path: B>K>F>L>I>D>E>A>C>H>G>J>B | Max alloc 0.0000 MB
# Trying n = 12 | removed 0 % | symmetrical - False
#     [nn          | n=12] Cost: 765.16 | Time: 0.0000s | Path: A>K>B>F>H>D>G>J>C>I>L>E>A | Max alloc 0.0000 MB
#     [a_star_min  | n=12] Cost: 676.92 | Time: 84.9707s | Path: A>E>F>G>H>D>J>C>L>I>K>B>A | Max alloc 1402.2891 MB
#     [a_star_avg  | n=12] Cost: 871.07 | Time: 0.0020s | Path: A>K>B>F>H>D>J>C>I>L>E>G>A | Max alloc 0.0000 MB
#     [aco         | n=12] Cost: 673.95 | Time: 1.4804s | Path: B>K>A>E>F>G>H>D>J>C>I>L>B | Max alloc 0.0000 MB
# Trying n = 12 | removed 20 % | symmetrical - True
#     [nn          | n=12] Cost: 659.30 | Time: 0.0000s | Path: A>C>B>F>K>G>E>L>J>D>I>H>A | Max alloc 0.0000 MB
#     [a_star_min  | n=12] Cost: 514.28 | Time: 73.4110s | Path: A>C>B>H>I>G>E>K>F>L>D>J>A | Max alloc 1211.6719 MB
#     [a_star_avg  | n=12] Cost: 620.68 | Time: 0.0020s | Path: A>C>B>F>K>G>E>L>D>J>I>H>A | Max alloc 0.0000 MB
#     [aco         | n=12] Cost: 529.75 | Time: 1.4923s | Path: E>G>K>F>L>D>J>A>C>B>H>I>E | Max alloc 0.0000 MB
# Trying n = 12 | removed 20 % | symmetrical - False
#     [nn          | n=12] Cost: 636.40 | Time: 0.0010s | Path: A>E>L>J>K>G>I>C>H>B>F>D>A | Max alloc 0.0000 MB
#     [a_star_min  | n=12] Cost: 636.40 | Time: 40.6838s | Path: A>E>L>J>K>G>I>C>H>B>F>D>A | Max alloc 684.4805 MB
#     [a_star_avg  | n=12] Cost: 636.40 | Time: 0.0019s | Path: A>E>L>J>K>G>I>C>H>B>F>D>A | Max alloc 0.0000 MB
#     [aco         | n=12] Cost: 636.40 | Time: 1.4774s | Path: C>H>B>F>D>A>E>L>J>K>G>I>C | Max alloc 0.0000 MB
# Trying n = 13 | removed 0 % | symmetrical - True
#     [nn          | n=13] Cost: 814.66 | Time: 0.0010s | Path: A>J>G>K>L>F>I>H>C>E>D>M>B>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=13] Cost: 811.66 | Time: 0.0040s | Path: A>J>G>K>L>F>I>H>C>D>M>E>B>A | Max alloc 0.0000 MB
#     [aco         | n=13] Cost: 731.14 | Time: 1.6849s | Path: A>J>H>C>E>D>M>B>I>F>L>K>G>A | Max alloc 0.0000 MB
# Trying n = 13 | removed 0 % | symmetrical - False
#     [nn          | n=13] Cost: 601.62 | Time: 0.0000s | Path: A>G>L>J>C>E>I>F>H>M>D>B>K>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=13] Cost: 601.62 | Time: 0.0030s | Path: A>G>L>J>C>E>I>F>H>M>D>B>K>A | Max alloc 0.0000 MB
#     [aco         | n=13] Cost: 599.69 | Time: 1.6870s | Path: H>F>I>E>C>J>L>G>A>K>B>D>M>H | Max alloc 0.0000 MB
# Trying n = 13 | removed 20 % | symmetrical - True
#     [nn          | n=13] Cost: 716.61 | Time: 0.0000s | Path: A>K>J>F>D>I>G>C>M>L>E>H>B>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=13] Cost: 748.99 | Time: 0.0040s | Path: A>K>J>F>D>B>H>E>L>C>M>G>I>A | Max alloc 0.0000 MB
#     [aco         | n=13] Cost: 676.03 | Time: 1.6672s | Path: J>A>D>I>K>G>M>C>L>E>H>B>F>J | Max alloc 0.0000 MB
# Trying n = 13 | removed 20 % | symmetrical - False
#     [nn          | n=13] Cost: 940.21 | Time: 0.0000s | Path: A>D>J>E>F>H>B>I>M>K>C>G>L>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=13] Cost: 897.08 | Time: 0.0040s | Path: A>D>J>E>F>H>B>I>M>K>C>L>G>A | Max alloc 0.0000 MB
#     [aco         | n=13] Cost: 730.70 | Time: 1.6757s | Path: H>L>F>E>J>D>G>A>C>K>I>M>B>H | Max alloc 0.0000 MB
# Trying n = 14 | removed 0 % | symmetrical - True
#     [nn          | n=14] Cost: 796.86 | Time: 0.0010s | Path: A>D>K>F>N>E>H>I>L>M>J>G>B>C>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=14] Cost: 796.86 | Time: 0.0040s | Path: A>D>K>F>N>E>H>I>L>M>J>G>B>C>A | Max alloc 0.0000 MB
#     [aco         | n=14] Cost: 783.83 | Time: 1.8937s | Path: E>H>N>F>K>A>D>C>B>G>J>M>I>L>E | Max alloc 0.0000 MB
# Trying n = 14 | removed 0 % | symmetrical - False
#     [nn          | n=14] Cost: 759.60 | Time: 0.0000s | Path: A>J>N>F>M>E>K>B>L>H>I>D>G>C>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=14] Cost: 759.60 | Time: 0.0030s | Path: A>J>N>F>M>E>K>B>L>H>I>D>G>C>A | Max alloc 0.0000 MB
#     [aco         | n=14] Cost: 731.05 | Time: 1.8935s | Path: N>J>A>E>K>B>L>H>I>D>G>C>M>F>N | Max alloc 0.0000 MB
# Trying n = 14 | removed 20 % | symmetrical - True
#     [nn          | n=14] Cost: 712.86 | Time: 0.0000s | Path: A>F>B>I>L>C>N>M>G>H>K>E>D>J>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=14] Cost: 712.86 | Time: 0.0040s | Path: A>F>B>I>L>C>N>M>G>H>K>E>D>J>A | Max alloc 0.0000 MB
#     [aco         | n=14] Cost: 648.14 | Time: 1.8708s | Path: L>I>B>C>N>F>A>K>E>D>J>H>M>G>L | Max alloc 0.0000 MB
# Trying n = 14 | removed 20 % | symmetrical - False
#     [nn          | n=14] Cost: 662.51 | Time: 0.0010s | Path: A>C>I>F>D>K>G>N>B>H>M>L>E>J>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=14] Cost: 662.51 | Time: 0.0030s | Path: A>C>I>F>D>K>G>N>B>H>M>L>E>J>A | Max alloc 0.0000 MB
#     [aco         | n=14] Cost: 662.51 | Time: 1.8767s | Path: D>K>G>N>B>H>M>L>E>J>A>C>I>F>D | Max alloc 0.0000 MB
# Trying n = 15 | removed 0 % | symmetrical - True
#     [nn          | n=15] Cost: 751.90 | Time: 0.0000s | Path: A>K>M>C>N>O>E>G>H>I>F>L>J>B>D>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=15] Cost: 751.90 | Time: 0.0040s | Path: A>K>M>C>N>O>E>G>H>I>F>L>J>B>D>A | Max alloc 0.0000 MB
#     [aco         | n=15] Cost: 683.33 | Time: 2.1179s | Path: M>K>A>O>C>N>D>B>J>L>F>H>I>G>E>M | Max alloc 0.0000 MB
# Trying n = 15 | removed 0 % | symmetrical - False
#     [nn          | n=15] Cost: 784.44 | Time: 0.0010s | Path: A>C>J>D>M>F>H>N>B>O>E>K>L>G>I>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=15] Cost: 784.44 | Time: 0.0040s | Path: A>C>J>D>M>F>H>N>B>O>E>K>L>G>I>A | Max alloc 0.0000 MB
#     [aco         | n=15] Cost: 772.10 | Time: 2.1183s | Path: E>K>H>F>M>D>L>G>I>C>J>A>N>O>B>E | Max alloc 0.0000 MB
# Trying n = 15 | removed 20 % | symmetrical - True
#     [nn          | n=15] Cost: 757.98 | Time: 0.0000s | Path: A>O>N>J>L>E>H>I>F>K>C>B>G>M>D>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=15] Cost: 757.98 | Time: 0.0050s | Path: A>O>N>J>L>E>H>I>F>K>C>B>G>M>D>A | Max alloc 0.0000 MB
#     [aco         | n=15] Cost: 757.98 | Time: 2.0869s | Path: O>N>J>L>E>H>I>F>K>C>B>G>M>D>A>O | Max alloc 0.0000 MB
# Trying n = 15 | removed 20 % | symmetrical - False
#     [nn          | n=15] Cost: 752.35 | Time: 0.0010s | Path: A>M>G>E>D>B>F>O>C>N>J>K>I>L>H>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=15] Cost: 671.54 | Time: 0.0050s | Path: A>M>G>E>D>B>F>O>C>N>J>K>H>I>L>A | Max alloc 0.0000 MB
#     [aco         | n=15] Cost: 650.50 | Time: 2.1009s | Path: K>J>N>I>O>L>B>E>D>M>A>G>H>F>C>K | Max alloc 0.0000 MB
# Trying n = 16 | removed 0 % | symmetrical - True
#     [nn          | n=16] Cost: 747.89 | Time: 0.0010s | Path: A>O>G>L>J>B>P>N>E>K>C>I>D>M>F>H>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=16] Cost: 747.89 | Time: 0.0060s | Path: A>O>G>L>J>B>P>N>E>K>C>I>D>M>F>H>A | Max alloc 0.0000 MB
#     [aco         | n=16] Cost: 730.26 | Time: 2.3611s | Path: D>M>F>H>L>A>O>G>J>B>P>N>E>K>C>I>D | Max alloc 0.0000 MB
# Trying n = 16 | removed 0 % | symmetrical - False
#     [nn          | n=16] Cost: 691.83 | Time: 0.0010s | Path: A>O>D>G>B>H>E>M>K>I>F>P>C>L>N>J>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=16] Cost: 691.83 | Time: 0.0060s | Path: A>O>D>G>B>H>E>M>K>I>F>P>C>L>N>J>A | Max alloc 0.0000 MB
#     [aco         | n=16] Cost: 615.92 | Time: 2.3545s | Path: C>P>F>I>K>M>E>H>B>O>D>G>A>L>J>N>C | Max alloc 0.0000 MB
# Trying n = 16 | removed 20 % | symmetrical - True
#     [nn          | n=16] Cost: 856.87 | Time: 0.0000s | Path: A>H>P>D>K>O>G>B>E>C>N>L>M>I>J>F>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=16] Cost: 856.87 | Time: 0.0050s | Path: A>H>P>D>K>O>G>B>E>C>N>L>M>I>J>F>A | Max alloc 0.0000 MB
#     [aco         | n=16] Cost: 847.63 | Time: 2.3331s | Path: H>P>A>B>E>C>N>L>M>I>J>F>K>D>O>G>H | Max alloc 0.0000 MB
# Trying n = 16 | removed 20 % | symmetrical - False
#     [nn          | n=16] Cost: 818.18 | Time: 0.0000s | Path: A>L>C>P>I>M>D>B>E>N>O>J>F>K>H>G>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=16] Cost: 981.73 | Time: 0.0060s | Path: A>L>C>P>I>M>D>B>E>N>F>K>H>G>J>O>A | Max alloc 0.0000 MB
#     [aco         | n=16] Cost: 805.97 | Time: 2.3363s | Path: K>H>G>A>L>B>M>D>I>P>C>E>N>O>J>F>K | Max alloc 0.0000 MB
# Trying n = 17 | removed 0 % | symmetrical - True
#     [nn          | n=17] Cost: 835.65 | Time: 0.0010s | Path: A>I>O>J>Q>H>F>D>G>K>N>E>B>C>L>M>P>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=17] Cost: 835.65 | Time: 0.0080s | Path: A>I>O>J>Q>H>F>D>G>K>N>E>B>C>L>M>P>A | Max alloc 0.0000 MB
#     [aco         | n=17] Cost: 723.86 | Time: 2.6289s | Path: D>G>P>L>M>B>C>J>I>O>A>E>Q>H>F>N>K>D | Max alloc 0.0000 MB
# Trying n = 17 | removed 0 % | symmetrical - False
#     [nn          | n=17] Cost: 1068.55 | Time: 0.0010s | Path: A>O>L>E>P>F>D>K>G>Q>J>B>N>M>C>H>I>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=17] Cost: 1044.86 | Time: 0.0080s | Path: A>O>L>E>P>F>D>K>G>Q>J>B>N>M>C>I>H>A | Max alloc 0.0000 MB
#     [aco         | n=17] Cost: 870.70 | Time: 2.6124s | Path: M>N>B>Q>J>A>O>L>E>P>F>G>K>D>H>C>I>M | Max alloc 0.0000 MB
# Trying n = 17 | removed 20 % | symmetrical - True
#     [nn          | n=17] Cost: 1012.51 | Time: 0.0000s | Path: A>O>L>F>M>G>B>K>P>J>Q>I>H>C>E>D>N>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=17] Cost: 977.21 | Time: 0.0070s | Path: A>O>L>F>M>G>B>K>P>J>H>I>C>Q>N>D>E>A | Max alloc 0.0000 MB
#     [aco         | n=17] Cost: 837.86 | Time: 2.5934s | Path: E>D>N>Q>I>H>C>A>O>L>B>G>M>F>K>P>J>E | Max alloc 0.0000 MB
# Trying n = 17 | removed 20 % | symmetrical - False
#     [nn          | n=17] Cost: 824.27 | Time: 0.0010s | Path: A>J>E>P>B>G>M>K>I>H>Q>L>D>N>C>F>O>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=17] Cost: 824.27 | Time: 0.0070s | Path: A>J>E>P>B>G>M>K>I>H>Q>L>D>N>C>F>O>A | Max alloc 0.0000 MB
#     [aco         | n=17] Cost: 801.08 | Time: 2.5966s | Path: D>N>C>F>O>J>A>G>B>P>E>M>K>I>H>Q>L>D | Max alloc 0.0000 MB
# Trying n = 18 | removed 0 % | symmetrical - True
#     [nn          | n=18] Cost: 1082.05 | Time: 0.0010s | Path: A>D>O>P>H>E>N>K>F>B>R>L>I>J>Q>M>G>C>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=18] Cost: 1082.05 | Time: 0.0100s | Path: A>D>O>P>H>E>N>K>F>B>R>L>I>J>Q>M>G>C>A | Max alloc 0.0000 MB
#     [aco         | n=18] Cost: 877.83 | Time: 2.8756s | Path: I>Q>J>M>G>H>O>P>D>A>E>N>K>F>B>R>L>C>I | Max alloc 0.0000 MB
# Trying n = 18 | removed 0 % | symmetrical - False
#     [nn          | n=18] Cost: 840.31 | Time: 0.0010s | Path: A>N>E>K>H>G>J>C>B>F>D>P>L>Q>I>O>M>R>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=18] Cost: 840.31 | Time: 0.0100s | Path: A>N>E>K>H>G>J>C>B>F>D>P>L>Q>I>O>M>R>A | Max alloc 0.0000 MB
#     [aco         | n=18] Cost: 840.31 | Time: 2.8837s | Path: A>N>E>K>H>G>J>C>B>F>D>P>L>Q>I>O>M>R>A | Max alloc 0.0000 MB
# Trying n = 18 | removed 20 % | symmetrical - True
#     [nn          | n=18] Cost: 1082.44 | Time: 0.0000s | Path: A>B>Q>E>C>L>G>D>F>N>I>P>J>K>M>O>H>R>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=18] Cost: 1054.86 | Time: 0.0100s | Path: A>B>Q>E>C>L>G>D>F>N>I>R>H>M>K>O>J>P>A | Max alloc 0.0000 MB
#     [aco         | n=18] Cost: 951.73 | Time: 2.8376s | Path: N>I>K>M>O>H>R>J>G>L>C>E>Q>B>A>P>D>F>N | Max alloc 0.0000 MB
# Trying n = 18 | removed 20 % | symmetrical - False
#     [nn          | n=18] Cost: 682.20 | Time: 0.0010s | Path: A>B>Q>K>G>F>C>L>D>J>N>M>H>P>R>O>I>E>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=18] Cost: 682.20 | Time: 0.0090s | Path: A>B>Q>K>G>F>C>L>D>J>N>M>H>P>R>O>I>E>A | Max alloc 0.0000 MB
#     [aco         | n=18] Cost: 662.77 | Time: 2.8355s | Path: B>A>O>I>E>F>G>C>L>D>J>N>M>H>P>R>K>Q>B | Max alloc 0.0000 MB
# Trying n = 19 | removed 0 % | symmetrical - True
#     [nn          | n=19] Cost: 945.99 | Time: 0.0000s | Path: A>K>I>D>P>E>O>M>N>S>F>C>H>Q>J>L>G>R>B>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=19] Cost: 945.99 | Time: 0.0120s | Path: A>K>I>D>P>E>O>M>N>S>F>C>H>Q>J>L>G>R>B>A | Max alloc 0.0000 MB
#     [aco         | n=19] Cost: 876.64 | Time: 3.1551s | Path: L>G>R>A>K>I>D>P>E>O>M>N>S>F>C>H>Q>J>B>L | Max alloc 0.0000 MB
# Trying n = 19 | removed 0 % | symmetrical - False
#     [nn          | n=19] Cost: 1000.32 | Time: 0.0010s | Path: A>S>K>P>O>Q>F>H>L>J>C>E>B>R>G>D>N>M>I>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=19] Cost: 1230.29 | Time: 0.0140s | Path: A>S>K>P>O>Q>F>H>L>J>C>E>B>R>D>N>M>I>G>A | Max alloc 0.0000 MB
#     [aco         | n=19] Cost: 1000.64 | Time: 3.1542s | Path: S>A>I>M>K>P>O>Q>L>F>H>G>C>J>R>B>E>D>N>S | Max alloc 0.0000 MB
# Trying n = 19 | removed 20 % | symmetrical - True
#     [nn          | n=19] Cost: 890.09 | Time: 0.0000s | Path: A>O>Q>P>N>E>R>I>H>C>D>S>M>K>B>J>L>G>F>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=19] Cost: 890.09 | Time: 0.0130s | Path: A>O>Q>P>N>E>R>I>H>C>D>S>M>K>B>J>L>G>F>A | Max alloc 0.0000 MB
#     [aco         | n=19] Cost: 868.73 | Time: 3.1073s | Path: S>M>K>B>J>L>G>F>A>O>Q>P>N>E>I>R>H>C>D>S | Max alloc 0.0000 MB
# Trying n = 19 | removed 20 % | symmetrical - False
#     [nn          | n=19] Cost: 950.81 | Time: 0.0000s | Path: A>I>R>P>H>D>F>J>L>E>N>Q>K>B>M>C>G>S>O>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=19] Cost: 950.81 | Time: 0.0130s | Path: A>I>R>P>H>D>F>J>L>E>N>Q>K>B>M>C>G>S>O>A | Max alloc 0.0000 MB
#     [aco         | n=19] Cost: 867.57 | Time: 3.1276s | Path: R>P>H>D>F>J>L>E>N>Q>K>B>M>C>G>S>A>I>O>R | Max alloc 0.0000 MB
# Trying n = 20 | removed 0 % | symmetrical - True
#     [nn          | n=20] Cost: 925.03 | Time: 0.0010s | Path: A>E>M>R>D>K>T>Q>H>S>I>G>P>B>L>O>J>N>C>F>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=20] Cost: 925.03 | Time: 0.0160s | Path: A>E>M>R>D>K>T>Q>H>S>I>G>P>B>L>O>J>N>C>F>A | Max alloc 0.0000 MB
#     [aco         | n=20] Cost: 912.78 | Time: 3.4471s | Path: B>P>G>I>K>T>Q>H>S>E>A>C>F>N>J>O>L>M>R>D>B | Max alloc 0.0000 MB
# Trying n = 20 | removed 0 % | symmetrical - False
#     [nn          | n=20] Cost: 1009.05 | Time: 0.0010s | Path: A>J>F>S>G>L>R>N>I>M>K>E>D>Q>H>T>P>B>C>O>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=20] Cost: 1009.05 | Time: 0.0160s | Path: A>J>F>S>G>L>R>N>I>M>K>E>D>Q>H>T>P>B>C>O>A | Max alloc 0.0000 MB
#     [aco         | n=20] Cost: 863.32 | Time: 3.4464s | Path: Q>J>A>S>F>G>L>R>N>I>P>B>C>O>E>K>M>D>H>T>Q | Max alloc 0.0000 MB
# Trying n = 20 | removed 20 % | symmetrical - True
#     [nn          | n=20] Cost: 976.16 | Time: 0.0000s | Path: A>F>D>P>Q>J>B>H>E>S>L>N>I>T>M>K>C>G>R>O>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=20] Cost: 939.69 | Time: 0.0150s | Path: A>F>D>P>Q>J>B>H>E>S>L>N>I>T>M>K>C>R>G>O>A | Max alloc 0.0000 MB
#     [aco         | n=20] Cost: 859.38 | Time: 3.3983s | Path: M>K>C>R>D>F>A>G>P>Q>J>O>H>B>E>S>I>N>L>T>M | Max alloc 0.0000 MB
# Trying n = 20 | removed 20 % | symmetrical - False
#     [nn          | n=20] Cost: 1007.62 | Time: 0.0000s | Path: A>L>J>K>D>C>E>M>I>N>Q>R>O>H>P>S>F>B>T>G>A | Max alloc 0.0000 MB
#     [a_star_avg  | n=20] Cost: 1007.62 | Time: 0.0160s | Path: A>L>J>K>D>C>E>M>I>N>Q>R>O>H>P>S>F>B>T>G>A | Max alloc 0.0000 MB
#     [aco         | n=20] Cost: 862.54 | Time: 3.4212s | Path: A>J>L>K>D>S>F>B>O>N>R>Q>H>P>I>M>C>E>T>G>A | Max alloc 0.0000 MB
